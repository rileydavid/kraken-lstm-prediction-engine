# %%
import pandas as pd
import requests

# Replace with the actual URL of your REST API


# Making a GET request to the API
response = requests.get(url)

# Ensure the request was successful
if response.status_code == 200:
    # Convert the JSON response to a pandas DataFrame
    data = response.json()
    df = pd.DataFrame(data)
    print(df)
else:
    print("Failed to fetch data: Status code", response.status_code)
# Out:
#                   bucket open_price       high        low close_price  \
# 0   2023-11-29T13:00:00Z  2057.9500  2062.3300  2053.3900   2055.9100
# 1   2023-11-29T14:00:00Z  2055.0200  2058.9000  2034.0200   2036.7500
# 2   2023-11-29T15:00:00Z  2036.7600  2040.5200  2021.5400   2033.0100
# 3   2023-11-29T16:00:00Z  2031.8300  2034.6500  2020.7400   2026.3500
# 4   2023-11-29T17:00:00Z  2026.3600  2037.1300  2020.8900        2034
# 5   2023-11-30T16:00:00Z  2034.9100  2038.9900  2030.8900   2035.9200
# 6   2023-11-30T17:00:00Z  2035.4200  2040.7900  2034.5700   2039.3700
# 7   2023-11-30T18:00:00Z  2039.3800  2043.9400  2038.1400   2039.1800
# 8   2023-11-30T19:00:00Z  2039.1800  2044.4400  2037.3200   2041.6000
# 9   2023-11-30T20:00:00Z  2041.5900  2045.8900  2040.3800   2045.4500
# 10  2023-11-30T21:00:00Z  2044.4100  2049.3900  2041.3600   2046.1900
# 11  2023-11-30T22:00:00Z  2046.2000  2050.2000  2044.7600   2044.8900
# ...

# %%
import dateparser
timestrings = ['50 hours ago']

for timestring in timestrings:
    dt = dateparser.parse(timestring)
    print(dt.strftime("%Y-%m-%d %H:%M"))
# Out:
# 2023-12-20 08:52

# %%
import pandas as pd

test = [
    {
        "bucket": "2023-09-02T14:00:00Z",
        "open_price": "1636.4800",
        "high": "1639.4400",
        "low": "1635.3500",
        "close_price": "1637.5600",
        "volume": "55.57362368",
        "count": 149,
        "symbol_id": 1
    },
    {
        "bucket": "2023-09-02T15:00:00Z",
        "open_price": "1637.6500",
        "high": "1644.5000",
        "low": "1637.6200",
        "close_price": "1638.7900",
        "volume": "424.77471463",
        "count": 266,
        "symbol_id": 1
    },
    {
        "bucket": "2023-09-02T16:00:00Z",
        "open_price": "1639",
        "high": "1640.8300",
        "low": "1635.5000",
        "close_price": "1636.1000",
        "volume": "284.19551761",
        "count": 212,
        "symbol_id": 1
    }
]


df = pd.DataFrame(test)
df.head()
# Out:
#                  bucket open_price       high        low close_price  \
# 0  2023-09-02T14:00:00Z  1636.4800  1639.4400  1635.3500   1637.5600
# 1  2023-09-02T15:00:00Z  1637.6500  1644.5000  1637.6200   1638.7900
# 2  2023-09-02T16:00:00Z       1639  1640.8300  1635.5000   1636.1000
#
#          volume  count  symbol_id
# 0   55.57362368    149          1
# 1  424.77471463    266          1
# 2  284.19551761    212          1

# %%
{
    "bucket": "2022-01-01T23:00:00Z",
    "close_price": "4042.000000000000"
}
