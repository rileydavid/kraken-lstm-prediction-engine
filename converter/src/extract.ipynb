# %%
import os 

os.listdir("/")
# Out:
# ['boot',
#  'home',
#  'etc',
#  'media',
#  'var',
#  'bin',
#  'dev',
#  'lib',
#  'lib32',
#  'lib64',
#  'libx32',
#  'mnt',
#  'opt',
#  'proc',
#  'root',
#  'run',
#  'sbin',
#  'snap',
#  'srv',
#  'sys',
#  'tmp',
#  'usr',
#  'cdrom',
#  'path']
