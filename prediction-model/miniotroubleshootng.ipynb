# %%
#!/usr/bin/python3
import os
import boto3
import sklearn.datasets
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import mlflow
import mlflow.sklearn
import sys

n_estimators = 10
max_depth = 5
random_state = 71

iris = sklearn.datasets.load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=random_state)

model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=random_state)
model.fit(X_train, y_train)

print(model.predict(X_test))
score = model.score(X_test, y_test)

mlflow.set_tracking_uri('http://127.0.0.1:5000')

expr_name = "random-forest21"  # create a new experiment (do not replace)
s3_bucket = "mlflow-models"  # replace this value
#mlflow.create_experiment(expr_name)
mlflow.create_experiment(expr_name, s3_bucket)
mlflow.set_experiment(expr_name)

mlflow.start_run()
mlflow.log_param("n_estimatores", n_estimators)
mlflow.log_param("max_depth", max_depth)
mlflow.log_param("random_state", random_state)
mlflow.log_metric("score", score)
#mlflow.set_tracking_uri("http://172.1.0.12:2000/mlflow-models/mlflow")

mlflow.log_artifact("test.txt")
mlflow.end_run()
# Out:
# [2 0 1 2 1 1 0 2 2 2 2 0 0 1 0 0 2 1 1 1 1 0 1 1 1 2 2 2 2 2 2 0 0 2 0 1 1
#  0 0 0 1 1 0 1 1]
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a> mlflow.log_metric("score", score)
#      <a href='vscode-notebook-cell:/home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb#W0sZmlsZQ%3D%3D?line=36'>37</a> #mlflow.set_tracking_uri("http://172.1.0.12:2000/mlflow-models/mlflow")
# ---> <a href='vscode-notebook-cell:/home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a> mlflow.log_artifact("test.txt")
#      <a href='vscode-notebook-cell:/home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb#W0sZmlsZQ%3D%3D?line=39'>40</a> mlflow.end_run()
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/fluent.py:974, in log_artifact(local_path, artifact_path)
#     951 """
#     952 Log a local file or directory as an artifact of the currently active run. If no run is
#     953 active, this method will create a new active run.
#    (...)
#     971         mlflow.log_artifact("features.txt")
#     972 """
#     973 run_id = _get_or_start_run().info.run_id
# --> 974 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/client.py:1142, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1107 def log_artifact(self, run_id, local_path, artifact_path=None) -> None:
#    1108     """
#    1109     Write a local file or directory to the remote ``artifact_uri``.
#    1110
#    (...)
#    1140         is_dir: False
#    1141     """
# -> 1142     self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:529, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     527     artifact_repo.log_artifacts(local_path, path_name)
#     528 else:
# --> 529     artifact_repo.log_artifact(local_path, artifact_path)
#
# File ~/.local/lib/python3.10/site-packages/mlflow/store/artifact/local_artifact_repo.py:36, in LocalArtifactRepository.log_artifact(self, local_file, artifact_path)
#      32 artifact_dir = (
#      33     os.path.join(self.artifact_dir, artifact_path) if artifact_path else self.artifact_dir
#      34 )
#      35 if not os.path.exists(artifact_dir):
# ---> 36     mkdir(artifact_dir)
#      37 try:
#      38     shutil.copy2(local_file, os.path.join(artifact_dir, os.path.basename(local_file)))
#
# File ~/.local/lib/python3.10/site-packages/mlflow/utils/file_utils.py:204, in mkdir(root, name)
#     202 except OSError as e:
#     203     if e.errno != errno.EEXIST or not os.path.isdir(target):
# --> 204         raise e
#     205 return target
#
# File ~/.local/lib/python3.10/site-packages/mlflow/utils/file_utils.py:201, in mkdir(root, name)
#     199 target = os.path.join(root, name) if name is not None else root
#     200 try:
# --> 201     os.makedirs(target)
#     202 except OSError as e:
#     203     if e.errno != errno.EEXIST or not os.path.isdir(target):
#
# File /usr/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /usr/lib/python3.10/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File /usr/lib/python3.10/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# PermissionError: [Errno 13] Permission denied: '/mlflow-models'

# %%
mlflow.end_run()

# %%
import mlflow

mlflow.set_experiment("your_experiment")

with mlflow.start_run():
    print(mlflow.get_artifact_uri())  # should print out a s3 bucket path
    mlflow.log_artifact("path/to/file")
# Out:
# s3://mlflow/model/37/cec671211609468e89df9f64efc68030/artifacts
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb Cell 3 line 7
#       <a href='vscode-notebook-cell:/home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb#Y143sZmlsZQ%3D%3D?line=4'>5</a> with mlflow.start_run():
#       <a href='vscode-notebook-cell:/home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb#Y143sZmlsZQ%3D%3D?line=5'>6</a>     print(mlflow.get_artifact_uri())  # should print out a s3 bucket path
# ----> <a href='vscode-notebook-cell:/home/rileydavid/Documents/google_drive/studium/BachelorThesis/PredictionModel/trading/prediction-model/miniotroubleshootng.ipynb#Y143sZmlsZQ%3D%3D?line=6'>7</a>     mlflow.log_artifact("path/to/file")
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/fluent.py:974, in log_artifact(local_path, artifact_path)
#     951 """
#     952 Log a local file or directory as an artifact of the currently active run. If no run is
#     953 active, this method will create a new active run.
#    (...)
#     971         mlflow.log_artifact("features.txt")
#     972 """
#     973 run_id = _get_or_start_run().info.run_id
# --> 974 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/client.py:1142, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1107 def log_artifact(self, run_id, local_path, artifact_path=None) -> None:
#    1108     """
#    1109     Write a local file or directory to the remote ``artifact_uri``.
#    1110
#    (...)
#    1140         is_dir: False
#    1141     """
# -> 1142     self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File ~/.local/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:529, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     527     artifact_repo.log_artifacts(local_path, path_name)
#     528 else:
# --> 529     artifact_repo.log_artifact(local_path, artifact_path)
#
# File ~/.local/lib/python3.10/site-packages/mlflow/store/artifact/s3_artifact_repo.py:165, in S3ArtifactRepository.log_artifact(self, local_file, artifact_path)
#     163     dest_path = posixpath.join(dest_path, artifact_path)
#     164 dest_path = posixpath.join(dest_path, os.path.basename(local_file))
# --> 165 self._upload_file(
#     166     s3_client=self._get_s3_client(), local_file=local_file, bucket=bucket, key=dest_path
#     167 )
#
# File ~/.local/lib/python3.10/site-packages/mlflow/store/artifact/s3_artifact_repo.py:158, in S3ArtifactRepository._upload_file(self, s3_client, local_file, bucket, key)
#     156 if environ_extra_args is not None:
#     157     extra_args.update(environ_extra_args)
# --> 158 s3_client.upload_file(Filename=local_file, Bucket=bucket, Key=key, ExtraArgs=extra_args)
#
# File ~/.local/lib/python3.10/site-packages/boto3/s3/inject.py:143, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     108 """Upload a file to an S3 object.
#     109
#     110 Usage::
#    (...)
#     140     transfer.
#     141 """
#     142 with S3Transfer(self, Config) as transfer:
# --> 143     return transfer.upload_file(
#     144         filename=Filename,
#     145         bucket=Bucket,
#     146         key=Key,
#     147         extra_args=ExtraArgs,
#     148         callback=Callback,
#     149     )
#
# File ~/.local/lib/python3.10/site-packages/boto3/s3/transfer.py:292, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     288 future = self._manager.upload(
#     289     filename, bucket, key, extra_args, subscribers
#     290 )
#     291 try:
# --> 292     future.result()
#     293 # If a client error was raised, add the backwards compatibility layer
#     294 # that raises a S3UploadFailedError. These specific errors were only
#     295 # ever thrown for upload_parts but now can be thrown for any related
#     296 # client error.
#     297 except ClientError as e:
#
# File ~/.local/lib/python3.10/site-packages/s3transfer/futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File ~/.local/lib/python3.10/site-packages/s3transfer/futures.py:266, in TransferCoordinator.result(self)
#     263 # Once done waiting, raise an exception if present or return the
#     264 # final result.
#     265 if self._exception:
# --> 266     raise self._exception
#     267 return self._result
#
# File ~/.local/lib/python3.10/site-packages/s3transfer/tasks.py:269, in SubmissionTask._main(self, transfer_future, **kwargs)
#     265     self._transfer_coordinator.set_status_to_running()
#     267     # Call the submit method to start submitting tasks to execute the
#     268     # transfer.
# --> 269     self._submit(transfer_future=transfer_future, **kwargs)
#     270 except BaseException as e:
#     271     # If there was an exception raised during the submission of task
#     272     # there is a chance that the final task that signals if a transfer
#    (...)
#     281
#     282     # Set the exception, that caused the process to fail.
#     283     self._log_and_set_exception(e)
#
# File ~/.local/lib/python3.10/site-packages/s3transfer/upload.py:591, in UploadSubmissionTask._submit(self, client, config, osutil, request_executor, transfer_future, bandwidth_limiter)
#     589 # Determine the size if it was not provided
#     590 if transfer_future.meta.size is None:
# --> 591     upload_input_manager.provide_transfer_size(transfer_future)
#     593 # Do a multipart upload if needed, otherwise do a regular put object.
#     594 if not upload_input_manager.requires_multipart_upload(
#     595     transfer_future, config
#     596 ):
#
# File ~/.local/lib/python3.10/site-packages/s3transfer/upload.py:244, in UploadFilenameInputManager.provide_transfer_size(self, transfer_future)
#     242 def provide_transfer_size(self, transfer_future):
#     243     transfer_future.meta.provide_transfer_size(
# --> 244         self._osutil.get_file_size(transfer_future.meta.call_args.fileobj)
#     245     )
#
# File ~/.local/lib/python3.10/site-packages/s3transfer/utils.py:247, in OSUtils.get_file_size(self, filename)
#     246 def get_file_size(self, filename):
# --> 247     return os.path.getsize(filename)
#
# File /usr/lib/python3.10/genericpath.py:50, in getsize(filename)
#      48 def getsize(filename):
#      49     """Return the size of a file, reported by os.stat()."""
# ---> 50     return os.stat(filename).st_size
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/file'

# %%
mlflow.end_run()

# %%
import os

os.environ["AWS_ACCESS_KEY_ID"] = "eITEO5kyE7hccuy7UTHv"
os.environ["AWS_SECRET_ACCESS_KEY"] = "5KBCscit30Z70bSVGIMvMBBoqV8ydn232o2MW9RA"
os.environ["MLFLOW_S3_ENDPOINT_URL"] = f"http://172.1.0.12:2000"

# %%
import mlflow

expr_name = "testing"  # create a new experiment (do not replace)
s3_bucket = "mlflow-models"  # replace this value
mlflow.create_experiment(expr_name)
mlflow.set_experiment(expr_name)

with mlflow.start_run():
    print(mlflow.get_artifact_uri())  # should print out an s3 bucket path
    
    # create a file to log
    with open("test1.txt", "w") as f:
        f.write("test")

    mlflow.log_artifact("test.txt")
# Out:
# s3://mlflow-models/288/71c2b6cf26734ac08366739bbc5153a0/artifacts

# %%
import boto3

import boto3

# Replace these with your Minio server details
minio_endpoint = 'http://172.1.0.12:2000'  # URL of your Minio server
access_key = 'eITEO5kyE7hccuy7UTHv'
secret_key = '5KBCscit30Z70bSVGIMvMBBoqV8ydn232o2MW9RA'
bucket_name = 'mlflow-models'  # Replace with the name of your Minio bucket
object_name = 'test_data.csv'  # Name for the object in the bucket

# Initialize the Minio client
minio_client = boto3.client('s3', endpoint_url=minio_endpoint, aws_access_key_id=access_key, aws_secret_access_key=secret_key)

# Specify the file you want to upload
local_file_path = './test_data.csv'  # Replace with the local file path

# Upload the file to Minio
try:
    minio_client.upload_file(local_file_path, bucket_name, object_name)
    print(f'Successfully uploaded {local_file_path} to {bucket_name}/{object_name}')
except Exception as e:
    print(f'Error uploading file: {str(e)}')

# %%
import boto3

import boto3

# Replace these with your Minio server details
minio_endpoint = 'http://minio-server:2001'  # URL of your Minio server
access_key = 'eITEO5kyE7hccuy7UTHv'
secret_key = '5KBCscit30Z70bSVGIMvMBBoqV8ydn232o2MW9RA'
bucket_name = 'mlflow-models'  # Replace with the name of your Minio bucket
object_name = 'test_data.csv'  # Name for the object in the bucket

# Initialize the Minio client
minio_client = boto3.client('s3', endpoint_url=minio_endpoint, aws_access_key_id=access_key, aws_secret_access_key=secret_key)

# Specify the file you want to upload
local_file_path = './test_data.csv'  # Replace with the local file path

# Upload the file to Minio
try:
    minio_client.download_file(bucket_name, object_name)
    print(f'Successfully uploaded {local_file_path} to {bucket_name}/{object_name}')
except Exception as e:
    print(f'Error uploading file: {str(e)}')
