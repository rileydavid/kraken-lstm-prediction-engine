# %% [markdown]
# ## Model Training Tracked with Mlflow

# %%
# check if everything here is needed
import mlflow
from mlflow import keras
from mlflow.models import infer_signature

from helper_functions import * 

import matplotlib.pyplot as plt
from keras.layers import LSTM, Dense, Dropout, BatchNormalization
from keras.models import load_model

# Extract features from the test data
from sklearn.metrics import explained_variance_score, mean_absolute_error, r2_score, mean_squared_error

from mlflow.models import infer_signature

from keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 2023-11-29 18:18:26.095039: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 18:18:26.095069: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 18:18:26.095098: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 18:18:26.101661: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   NVIDIA GeForce GTX 1060 6GB, compute capability 6.1
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# 2023-11-29 18:18:27.937490: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:27.942446: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:27.942611: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:27.942948: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %% [markdown]
# ## Data Prep

# %%
def data_prep(lstm_data):
    # Data preperation
    lstm_data = lstm_data.drop(columns=['open_price', 'high', 'low'], axis=1)

    lstm_data = process_timestamp(lstm_data, fill=True)
    lstm_data = add_feature_date(lstm_data)
    lstm_data = add_holiday_feature(lstm_data)
    lstm_data = apply_cyclic_encoding(lstm_data, columms=['hour', 'day_of_week', 'month'])
    lstm_data = apply_day_of_month_encoding(lstm_data)
    lstm_data = normalize_year(lstm_data) # has to be updated yearly 
    lstm_data['close_price_true'] =  lstm_data['close_price']
    lstm_data = apply_log_scaler(lstm_data, columns=['close_price', 'volume', 'count'])
    lstm_data = add_feature_lag(lstm_data, lags=[1,4,6,12,168])
    lstm_data = simple_moving_average(lstm_data, window_sizes=[6,12], columns=['close_price'])
    lstm_data = exponential_moving_average(lstm_data, span_sizes=[6,12], columns=['close_price'])

    lstm_data = lstm_data.drop(columns=['symbol_id', 'hour', 'day_of_week', 'day_of_month', 'month', 'year'], axis=1)

    lstm_data = lstm_data.dropna()

    return lstm_data

# %%
# Data preperation
file_path = 'kraken_ohlc_hour_count.csv'
lstm_data = pd.read_csv(file_path)
lstm_data = data_prep(lstm_data)
lstm_data.head(10)
# Out:
#                        bucket  close_price    volume     count  is_weekend  \
# 168 2015-08-14 14:00:00+00:00     1.099205  3.931159  1.098612           0
# 169 2015-08-14 15:00:00+00:00     1.099205  0.000000  0.000000           0
# 170 2015-08-14 16:00:00+00:00     1.073096  2.638756  0.693147           0
# 171 2015-08-14 17:00:00+00:00     1.033184  5.380558  2.079442           0
# 172 2015-08-14 18:00:00+00:00     1.057790  5.303305  1.386294           0
# 173 2015-08-14 19:00:00+00:00     1.064711  5.772507  2.772589           0
# 174 2015-08-14 20:00:00+00:00     1.108563  7.606771  3.871201           0
# 175 2015-08-14 21:00:00+00:00     1.095273  6.589037  2.397895           0
# 176 2015-08-14 22:00:00+00:00     1.047319  5.667998  2.397895           0
# 177 2015-08-14 23:00:00+00:00     1.029619  6.906667  2.995732           0
#
#      is_holiday      hour_cos  hour_sin  day_of_week_cos  day_of_week_sin  \
# 168           0 -8.660254e-01 -0.500000        -0.900969        -0.433884
# 169           0 -7.071068e-01 -0.707107        -0.900969        -0.433884
# 170           0 -5.000000e-01 -0.866025        -0.900969        -0.433884
# 171           0 -2.588190e-01 -0.965926        -0.900969        -0.433884
# 172           0 -1.836970e-16 -1.000000        -0.900969        -0.433884
# 173           0  2.588190e-01 -0.965926        -0.900969        -0.433884
# 174           0  5.000000e-01 -0.866025        -0.900969        -0.433884
# 175           0  7.071068e-01 -0.707107        -0.900969        -0.433884
# 176           0  8.660254e-01 -0.500000        -0.900969        -0.433884
# 177           0  9.659258e-01 -0.258819        -0.900969        -0.433884
#
#      ...  close_price_true  close_lag1  close_lag4  close_lag6  close_lag12  \
# 168  ...           2.00178    1.131402    1.131402    1.093533     1.085189
# 169  ...           2.00178    1.099205    1.131402    1.093533     1.071584
# 170  ...           1.92442    1.099205    1.131402    1.131402     1.071584
# 171  ...           1.81000    1.073096    1.131402    1.131402     1.071584
# 172  ...           1.88000    1.033184    1.099205    1.131402     1.071584
# 173  ...           1.90000    1.057790    1.099205    1.131402     1.093533
# 174  ...           2.03000    1.064711    1.073096    1.099205     1.093533
# 175  ...           1.99000    1.108563    1.033184    1.099205     1.093533
# 176  ...           1.85000    1.095273    1.057790    1.073096     1.131402
# 177  ...           1.80000    1.047319    1.064711    1.033184     1.131402
#
#      close_lag168  sma_6_close_price  sma_12_close_price  ema_6_close_price  \
# 168      1.386294           1.119724            1.099312           1.113550
# 169      1.386294           1.120670            1.101614           1.109451
# 170      1.386294           1.110952            1.101740           1.099064
# 171      1.386294           1.094583            1.098540           1.080241
# 172      1.386294           1.082314            1.097391           1.073827
# 173      1.386294           1.071199            1.094989           1.071222
# 174      1.386294           1.072758            1.096241           1.081891
# 175      1.386294           1.072103            1.096386           1.085714
# 176      1.386294           1.067807            1.089379           1.074744
# 177      1.386294           1.067213            1.080898           1.061851
#
#      ema_12_close_price
# 168            1.097994
# 169            1.098180
# 170            1.094321
# 171            1.084915
# 172            1.080742
# 173            1.078276
# 174            1.082935
# 175            1.084834
# 176            1.079062
# 177            1.071456
#
# [10 rows x 25 columns]

# %%
lstm_test = lstm_data.iloc[int(len(lstm_data)*0.99):] 
lstm_data = lstm_data.iloc[:int(len(lstm_data)*0.99)]

# %%
len(lstm_test)
# Out:
# 713

# %%
len(lstm_data)
# Out:
# 70527

# %%
def create_sequences_np(data, features, lookback, datatype=np.float16):
    data_array = data[features].to_numpy()
    X, y = [], []
    for i in range(lookback, len(data_array)):
        X.append(data_array[i-lookback:i])
        y.append(data_array[i, data.columns.get_loc('close_price')])
    return np.array(X).astype(datatype), np.array(y).astype(datatype)

features = ['is_holiday', 'close_price', 'volume', 'is_weekend', 'count',
             'hour_cos', 'hour_sin', 'day_of_week_cos', 
            'day_of_week_sin', 'month_cos', 'month_sin', 
            'day_of_month_sin', 'day_of_month_cos', 'year_normalized', 'close_lag12', 'close_lag168', 'ema_6_close_price', 'ema_12_close_price']

lookback = 24
X, y = create_sequences_np(lstm_data, features, lookback)

# %% [markdown]
# ## Model Training

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam

n_features = len(features)  # Number of features used
epochs = 50
units_lstm_1 = n_features * lookback
units_lstm_2 = n_features * lookback
dropout_layer_1 = 0.2
dropout_layer_2 = 0.2

print(units_lstm_1)
print(units_lstm_2)

return_sequences_lstm_1 = True
return_sequences_lstm_2 = False

dense_units = 1 

optimizer = 'adam'
loss = 'mean_absolute_error'

training_validation_split = 0.8

batch_size = 16

# LSTM model
model = Sequential()
model.add(LSTM(units=units_lstm_1,return_sequences=return_sequences_lstm_1, input_shape=(lookback, n_features))) # 1
model.add(Dropout(dropout_layer_1))
model.add(LSTM(units=units_lstm_2, return_sequences=return_sequences_lstm_2)) # 2
model.add(Dropout(dropout_layer_2))
model.add(Dense(units=dense_units))

# Adam(learning_rate=0.001)

model.compile(optimizer='adam', loss=loss, metrics=['mean_absolute_error', 'mean_squared_error'])

# split point at 20 percent 
split_idx = int(len(X) * training_validation_split)

# validation set with the last 20 percent of the dataset 
X_train, X_val = X[:split_idx], X[split_idx:]
y_train, y_val = y[:split_idx], y[split_idx:]

print(model.summary())

# maybe 43 epochs seems to have a good loss 
model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))
# Out:
# 432
# 432
# 2023-11-29 18:18:30.938617: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:30.938836: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:30.938960: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:31.451489: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:31.451678: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:31.451816: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-29 18:18:31.451912: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4632 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2023-11-29 18:18:31.644735: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 432)           779328
#
#  dropout (Dropout)           (None, 24, 432)           0
#
#  lstm_1 (LSTM)               (None, 432)               1494720
#
#  dropout_1 (Dropout)         (None, 432)               0
#
#  dense (Dense)               (None, 1)                 433
#
# =================================================================
# Total params: 2274481 (8.68 MB)
# Trainable params: 2274481 (8.68 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/50
# 2023-11-29 18:18:35.237507: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-11-29 18:18:36.421736: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f868c175790 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-29 18:18:36.421760: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1060 6GB, Compute Capability 6.1
# 2023-11-29 18:18:36.427640: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-29 18:18:36.541602: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3526/3526 [==============================] - 46s 12ms/step - loss: 0.2068 - mean_absolute_error: 0.2068 - mean_squared_error: 0.0900 - val_loss: 0.0871 - val_mean_absolute_error: 0.0871 - val_mean_squared_error: 0.0109
# Epoch 2/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1571 - mean_absolute_error: 0.1571 - mean_squared_error: 0.0433 - val_loss: 0.1722 - val_mean_absolute_error: 0.1722 - val_mean_squared_error: 0.0326
# Epoch 3/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1397 - mean_absolute_error: 0.1397 - mean_squared_error: 0.0343 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716 - val_mean_squared_error: 0.0065
# Epoch 4/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1306 - mean_absolute_error: 0.1306 - mean_squared_error: 0.0306 - val_loss: 0.0658 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0055
# Epoch 5/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1220 - mean_absolute_error: 0.1220 - mean_squared_error: 0.0267 - val_loss: 0.0720 - val_mean_absolute_error: 0.0720 - val_mean_squared_error: 0.0072
# Epoch 6/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1153 - mean_absolute_error: 0.1153 - mean_squared_error: 0.0238 - val_loss: 0.1651 - val_mean_absolute_error: 0.1651 - val_mean_squared_error: 0.0313
# Epoch 7/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1105 - mean_absolute_error: 0.1105 - mean_squared_error: 0.0219 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - val_mean_squared_error: 0.0034
# Epoch 8/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1046 - mean_absolute_error: 0.1046 - mean_squared_error: 0.0197 - val_loss: 0.1688 - val_mean_absolute_error: 0.1688 - val_mean_squared_error: 0.0306
# Epoch 9/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.1023 - mean_absolute_error: 0.1023 - mean_squared_error: 0.0190 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0027
# Epoch 10/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0979 - mean_absolute_error: 0.0979 - mean_squared_error: 0.0175 - val_loss: 0.0393 - val_mean_absolute_error: 0.0393 - val_mean_squared_error: 0.0024
# Epoch 11/50
# 3526/3526 [==============================] - 41s 11ms/step - loss: 0.0941 - mean_absolute_error: 0.0941 - mean_squared_error: 0.0162 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - val_mean_squared_error: 0.0040
# Epoch 12/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0908 - mean_absolute_error: 0.0908 - mean_squared_error: 0.0150 - val_loss: 0.0418 - val_mean_absolute_error: 0.0418 - val_mean_squared_error: 0.0025
# Epoch 13/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0877 - mean_absolute_error: 0.0877 - mean_squared_error: 0.0141 - val_loss: 0.0395 - val_mean_absolute_error: 0.0395 - val_mean_squared_error: 0.0024
# Epoch 14/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.0850 - mean_absolute_error: 0.0850 - mean_squared_error: 0.0133 - val_loss: 0.0287 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0013
# Epoch 15/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.0826 - mean_absolute_error: 0.0826 - mean_squared_error: 0.0138 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681 - val_mean_squared_error: 0.0056
# Epoch 16/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.0799 - mean_absolute_error: 0.0799 - mean_squared_error: 0.0118 - val_loss: 0.0264 - val_mean_absolute_error: 0.0264 - val_mean_squared_error: 0.0011
# Epoch 17/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0769 - mean_absolute_error: 0.0769 - mean_squared_error: 0.0110 - val_loss: 0.0270 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0011
# Epoch 18/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0758 - mean_absolute_error: 0.0758 - mean_squared_error: 0.0107 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - val_mean_squared_error: 0.0047
# Epoch 19/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0742 - mean_absolute_error: 0.0742 - mean_squared_error: 0.0102 - val_loss: 0.0324 - val_mean_absolute_error: 0.0324 - val_mean_squared_error: 0.0016
# Epoch 20/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0734 - mean_absolute_error: 0.0734 - mean_squared_error: 0.0100 - val_loss: 0.0276 - val_mean_absolute_error: 0.0276 - val_mean_squared_error: 0.0013
# Epoch 21/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0714 - mean_absolute_error: 0.0714 - mean_squared_error: 0.0095 - val_loss: 0.0932 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0093
# Epoch 22/50
# 3526/3526 [==============================] - 38s 11ms/step - loss: 0.0702 - mean_absolute_error: 0.0702 - mean_squared_error: 0.0091 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - val_mean_squared_error: 0.0036
# Epoch 23/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0710 - mean_absolute_error: 0.0710 - mean_squared_error: 0.0649 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - val_mean_squared_error: 0.0037
# Epoch 24/50
# 3526/3526 [==============================] - 37s 11ms/step - loss: 0.0674 - mean_absolute_error: 0.0674 - mean_squared_error: 0.0084 - val_loss: 0.0801 - val_mean_absolute_error: 0.0801 - val_mean_squared_error: 0.0073
# Epoch 25/50
# 3526/3526 [==============================] - 38s 11ms/step - loss: 0.0669 - mean_absolute_error: 0.0669 - mean_squared_error: 0.0084 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - val_mean_squared_error: 0.0042
# Epoch 26/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - mean_squared_error: 0.0079 - val_loss: 0.0867 - val_mean_absolute_error: 0.0867 - val_mean_squared_error: 0.0084
# Epoch 27/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.0644 - mean_absolute_error: 0.0644 - mean_squared_error: 0.0075 - val_loss: 0.0829 - val_mean_absolute_error: 0.0829 - val_mean_squared_error: 0.0073
# Epoch 28/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0637 - mean_absolute_error: 0.0637 - mean_squared_error: 0.0074 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471 - val_mean_squared_error: 0.0028
# Epoch 29/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0635 - mean_absolute_error: 0.0635 - mean_squared_error: 0.0073 - val_loss: 0.1114 - val_mean_absolute_error: 0.1114 - val_mean_squared_error: 0.0130
# Epoch 30/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0623 - mean_absolute_error: 0.0623 - mean_squared_error: 0.0071 - val_loss: 0.0212 - val_mean_absolute_error: 0.0212 - val_mean_squared_error: 7.3668e-04
# Epoch 31/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0614 - mean_absolute_error: 0.0614 - mean_squared_error: 0.0068 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - val_mean_squared_error: 0.0029
# Epoch 32/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0613 - mean_absolute_error: 0.0613 - mean_squared_error: 0.0068 - val_loss: 0.0379 - val_mean_absolute_error: 0.0379 - val_mean_squared_error: 0.0019
# Epoch 33/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0600 - mean_absolute_error: 0.0600 - mean_squared_error: 0.0065 - val_loss: 0.0832 - val_mean_absolute_error: 0.0832 - val_mean_squared_error: 0.0077
# Epoch 34/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0604 - mean_absolute_error: 0.0604 - mean_squared_error: 0.0106 - val_loss: 0.0208 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 7.6164e-04
# Epoch 35/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0587 - mean_absolute_error: 0.0587 - mean_squared_error: 0.0063 - val_loss: 0.0188 - val_mean_absolute_error: 0.0188 - val_mean_squared_error: 5.8013e-04
# Epoch 36/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0578 - mean_absolute_error: 0.0578 - mean_squared_error: 0.0061 - val_loss: 0.0463 - val_mean_absolute_error: 0.0463 - val_mean_squared_error: 0.0025
# Epoch 37/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0584 - mean_absolute_error: 0.0584 - mean_squared_error: 0.0229 - val_loss: 0.0459 - val_mean_absolute_error: 0.0459 - val_mean_squared_error: 0.0026
# Epoch 38/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0575 - mean_absolute_error: 0.0575 - mean_squared_error: 0.0060 - val_loss: 0.0153 - val_mean_absolute_error: 0.0153 - val_mean_squared_error: 4.0933e-04
# Epoch 39/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0563 - mean_absolute_error: 0.0563 - mean_squared_error: 0.0058 - val_loss: 0.0166 - val_mean_absolute_error: 0.0166 - val_mean_squared_error: 5.0619e-04
# Epoch 40/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0559 - mean_absolute_error: 0.0559 - mean_squared_error: 0.0057 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704 - val_mean_squared_error: 0.0057
# Epoch 41/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0552 - mean_absolute_error: 0.0552 - mean_squared_error: 0.0057 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - val_mean_squared_error: 0.0026
# Epoch 42/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - mean_squared_error: 0.0055 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652 - val_mean_squared_error: 0.0047
# Epoch 43/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0542 - mean_absolute_error: 0.0542 - mean_squared_error: 0.0055 - val_loss: 0.0186 - val_mean_absolute_error: 0.0186 - val_mean_squared_error: 5.7267e-04
# Epoch 44/50
# 3526/3526 [==============================] - 39s 11ms/step - loss: 0.0539 - mean_absolute_error: 0.0539 - mean_squared_error: 0.0054 - val_loss: 0.0221 - val_mean_absolute_error: 0.0221 - val_mean_squared_error: 7.6895e-04
# Epoch 45/50
# 3526/3526 [==============================] - 38s 11ms/step - loss: 0.0537 - mean_absolute_error: 0.0537 - mean_squared_error: 0.0054 - val_loss: 0.0378 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0018
# Epoch 46/50
# 3526/3526 [==============================] - 41s 12ms/step - loss: 0.0532 - mean_absolute_error: 0.0532 - mean_squared_error: 0.0053 - val_loss: 0.0410 - val_mean_absolute_error: 0.0410 - val_mean_squared_error: 0.0020
# Epoch 47/50
# 3526/3526 [==============================] - 42s 12ms/step - loss: 0.0528 - mean_absolute_error: 0.0528 - mean_squared_error: 0.0053 - val_loss: 0.0427 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0021
# Epoch 48/50
# 3526/3526 [==============================] - 42s 12ms/step - loss: 0.0523 - mean_absolute_error: 0.0523 - mean_squared_error: 0.0052 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - val_mean_squared_error: 0.0029
# Epoch 49/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0514 - mean_absolute_error: 0.0514 - mean_squared_error: 0.0050 - val_loss: 0.0259 - val_mean_absolute_error: 0.0259 - val_mean_squared_error: 9.9207e-04
# Epoch 50/50
# 3526/3526 [==============================] - 40s 11ms/step - loss: 0.0517 - mean_absolute_error: 0.0517 - mean_squared_error: 0.0051 - val_loss: 0.0487 - val_mean_absolute_error: 0.0487 - val_mean_squared_error: 0.0028

# %%
## load non-training data: + 12hour lookback 

test_file_path = 'kraken_ohlc_hour_count_unseen.csv'

# Data preperation
#test_lstm = data_prep(test_file_path)
#original_lstm_test = pd.read_csv(test_file_path) 

lstm_test.head(100)
# Out:
#                          bucket  close_price    volume     count  is_weekend  \
# 70695 2023-08-31 05:00:00+00:00     7.440998  4.598232  4.787492           0
# 70696 2023-08-31 06:00:00+00:00     7.441584  5.615610  5.198497           0
# 70697 2023-08-31 07:00:00+00:00     7.442487  5.063637  4.820282           0
# 70698 2023-08-31 08:00:00+00:00     7.442469  7.088198  5.463832           0
# 70699 2023-08-31 09:00:00+00:00     7.441326  4.171881  4.700480           0
# ...                         ...          ...       ...       ...         ...
# 70790 2023-09-04 04:00:00+00:00     7.401927  3.225643  4.605170           0
# 70791 2023-09-04 05:00:00+00:00     7.400016  5.416159  4.867534           0
# 70792 2023-09-04 06:00:00+00:00     7.401195  4.916783  4.820282           0
# 70793 2023-09-04 07:00:00+00:00     7.402269  5.335911  4.820282           0
# 70794 2023-09-04 08:00:00+00:00     7.402128  4.513259  4.905275           0
#
#        is_holiday      hour_cos  hour_sin  day_of_week_cos  day_of_week_sin  \
# 70695           0  2.588190e-01  0.965926        -0.900969         0.433884
# 70696           0  6.123234e-17  1.000000        -0.900969         0.433884
# 70697           0 -2.588190e-01  0.965926        -0.900969         0.433884
# 70698           0 -5.000000e-01  0.866025        -0.900969         0.433884
# 70699           0 -7.071068e-01  0.707107        -0.900969         0.433884
# ...           ...           ...       ...              ...              ...
# 70790           1  5.000000e-01  0.866025         1.000000         0.000000
# 70791           1  2.588190e-01  0.965926         1.000000         0.000000
# 70792           1  6.123234e-17  1.000000         1.000000         0.000000
# 70793           1 -2.588190e-01  0.965926         1.000000         0.000000
# 70794           1 -5.000000e-01  0.866025         1.000000         0.000000
#
#        ...  close_price_true  close_lag1  close_lag4  close_lag6  close_lag12  \
# 70695  ...           1703.45    7.439700    7.438484    7.441977     7.439318
# 70696  ...           1704.45    7.440998    7.438948    7.439242     7.441103
# 70697  ...           1705.99    7.441584    7.438125    7.438484     7.439929
# 70698  ...           1705.96    7.442487    7.439700    7.438948     7.440880
# 70699  ...           1704.01    7.442469    7.440998    7.438125     7.441115
# ...    ...               ...         ...         ...         ...          ...
# 70790  ...           1638.14    7.401482    7.399783    7.400370     7.395605
# 70791  ...           1635.01    7.401927    7.398590    7.400492     7.397862
# 70792  ...           1636.94    7.400016    7.402244    7.399783     7.401060
# 70793  ...           1638.70    7.401195    7.401482    7.398590     7.402281
# 70794  ...           1638.47    7.402269    7.401927    7.402244     7.404723
#
#        close_lag168  sma_6_close_price  sma_12_close_price  ema_6_close_price  \
# 70695      7.423652           7.439249            7.440081           7.439855
# 70696      7.424332           7.439640            7.440122           7.440349
# 70697      7.423813           7.440307            7.440335           7.440960
# 70698      7.422738           7.440894            7.440467           7.441391
# 70699      7.419285           7.441427            7.440485           7.441373
# ...             ...                ...                 ...                ...
# 70790      7.408791           7.400753            7.400984           7.401172
# 70791      7.404565           7.400674            7.401163           7.400842
# 70792      7.404967           7.400909            7.401174           7.400943
# 70793      7.403268           7.401522            7.401173           7.401321
# 70794      7.403853           7.401503            7.400957           7.401552
#
#        ema_12_close_price
# 70695            7.440494
# 70696            7.440662
# 70697            7.440942
# 70698            7.441177
# 70699            7.441200
# ...                   ...
# 70790            7.400790
# 70791            7.400671
# 70792            7.400752
# 70793            7.400985
# 70794            7.401161
#
# [100 rows x 25 columns]

# %%
X.shape
# Out:
# (70503, 24, 18)

# %%
lstm_data.iloc[-1]
# Out:
# bucket                2023-08-31 04:00:00+00:00
# close_price                              7.4397
# volume                                 6.957969
# count                                  5.793014
# is_weekend                                    0
# is_holiday                                    0
# hour_cos                                    0.5
# hour_sin                               0.866025
# day_of_week_cos                       -0.900969
# day_of_week_sin                        0.433884
# month_cos                                  -0.5
# month_sin                             -0.866025
# day_of_month_sin                      -0.201299
# day_of_month_cos                        0.97953
# year_normalized                        0.888889
# close_price_true                        1701.24
# close_lag1                             7.438125
# close_lag4                             7.439242
# close_lag6                             7.440475
# close_lag12                            7.438972
# close_lag168                           7.424833
# sma_6_close_price                      7.439413
# sma_12_close_price                     7.439941
# ema_6_close_price                      7.439398
# ema_12_close_price                     7.440402
# Name: 70694, dtype: object

# %%
# Start the loop to predict each next hour and collect the actual and predicted prices
predicted_prices = []
actual_prices = lstm_test['close_price_true'].values[lookback:]  # actual prices without log transformation
timestamps = lstm_test['bucket'].values[lookback:]  # corresponding timestamps

for i in range(lookback, len(lstm_test)):
    last_sequence = lstm_test.iloc[i-lookback:i][features].values.reshape((1, lookback, len(features)))
    last_sequence = np.array(last_sequence).astype(np.float16)
    predicted_log_price = model.predict(last_sequence)
    predicted_price = np.expm1(predicted_log_price)[0, 0]  # inverse log transformation
    predicted_prices.append(predicted_price)

# Convert predictions to a numpy array
predicted_prices = np.array(predicted_prices)

# Calculate the metrics
mse_value = mean_squared_error(actual_prices, predicted_prices)
mae_value = mean_absolute_error(actual_prices, predicted_prices)
rmse_value = np.sqrt(mse_value)
mape_value = np.mean(np.abs((actual_prices - predicted_prices) / actual_prices)) * 100
r2_value = r2_score(actual_prices, predicted_prices)
explained_variance = explained_variance_score(actual_prices, predicted_prices)

print('mse', mse_value)
print('mae', mae_value)
print('rmse', rmse_value)
print('mape', mape_value)
print('r2', r2_value)
print('explained_variance', explained_variance)
# Out:
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 50
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 100
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 150
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 200
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 250
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 300
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 350
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 400
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 450
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 500
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 550
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 600
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 650
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 700
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# mse 6982.028886357039
# mae 80.17664731494921
# rmse 83.55853568820505
# mape 4.957154836518101
# r2 -11.405571301854708
# explained_variance 0.016132972712514237

# %%
test = np.array(predicted_prices)
test = np.subtract(test, 100)

# %%
np.mean(predicted_prices) - np.mean(actual_prices)
# Out:
# 80.60190130624096

# %%
# Plotting the results
plt.figure(figsize=(15, 7))
plt.plot(timestamps, actual_prices, label='Actual Prices', color='blue')
plt.plot(timestamps, predicted_prices, label='Predicted Prices', color='orange')
plt.xlabel('Date/Time')
plt.ylabel('Close Price')

plt.title('LSTM Model Predictions vs Actual Prices')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
plt.show()

# %%
# Plotting the results
plt.figure(figsize=(15, 7))
plt.plot(timestamps, actual_prices, label='Actual Prices', color='blue')
plt.plot(timestamps, test, label='Predicted Prices', color='orange')
plt.xlabel('Date/Time')
plt.ylabel('Close Price')

plt.title('LSTM Model Predictions vs Actual Prices')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
plt.show()

# %%
# with smoothing
from scipy.signal import savgol_filter

test_smooth = savgol_filter(test, 25, 4) # window size 51, polynomial order 3

# Plotting the results
plt.figure(figsize=(15, 7))
plt.plot(timestamps, actual_prices, label='Actual Prices', color='blue')
plt.plot(timestamps, test_smooth, label='Predicted Prices', color='orange')
plt.xlabel('Date/Time')
plt.ylabel('Close Price')

plt.title('LSTM Model Predictions vs Actual Prices')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()  # Adjusts plot to ensure everything fits without overlapping
plt.show()

# %%
## Plotting the validation set 

y_pred = model.predict(X_val)

y_val_true = np.expm1(y_val)
y_pred_true = np.expm1(y_pred)

plt.figure(figsize=(15, 7))
plt.plot(y_val_true, label='Actual Values')
plt.plot(y_pred_true, label='Predicted Values')
plt.title('LSTM Model Validation Plot')
plt.xlabel('Time')
plt.ylabel('Close Price')
#plt.yscale('log')
plt.legend()
plt.tight_layout()
# Out:
# 441/441 [==============================] - 2s 5ms/step
